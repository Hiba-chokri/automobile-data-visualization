# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)
# %matplotlib inline

# %%
auto = pd.read_csv(r'C:\Users\cap\Downloads\clean_auto_data.csv')

# %%
auto.head()
# Out:
#    Unnamed: 0  symboling  normalized-losses         make num-of-doors  \
# 0           0          3                122  alfa-romero          two
# 1           1          3                122  alfa-romero          two
# 2           2          1                122  alfa-romero          two
# 3           3          2                164         audi         four
# 4           4          2                164         audi         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    city-mpg  highway-mpg    price city-L/100km highway-L/100km  \
# ...

# %%
#disturbution of one variable
sns.displot(auto['normalized-losses'])

# %%
sns.displot(auto['city-mpg'],kde=False,rug=True)

# %%
#bivariable
#diff kinds(scatter,resid,hex,rug,kde)
sns.jointplot(auto['wheel-base'],auto['length'], kind="hex")
# Out:
# C:\Users\cap\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pairplot(auto[['normalized-losses','wheel-base','length']])

# %%
#a categorecal,and continues variables
sns.stripplot(auto['horsepower-binned'],auto['price'])
# Out:
# <AxesSubplot:xlabel='horsepower-binned', ylabel='price'>

# %%
sns.boxplot(auto['horsepower-binned'],auto['wheel-base'], hue= auto['num-of-doors'])
# Out:
# C:\Users\cap\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='horsepower-binned', ylabel='wheel-base'>

# %%
sns.barplot(auto['body-style'], auto['highway-L/100km'],hue=auto['engine-location'])
# Out:
# C:\Users\cap\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='body-style', ylabel='highway-L/100km'>

# %%
#factorplot
#vration types of kind input(bar,strip,point,count,violin)
sns.catplot(x="horsepower-binned",
               y="price",
               col="engine-location",
               data=auto,
               kind="swarm")
# Out:
# C:\Users\cap\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 5.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.lmplot(x="city-L/100km",y="normalized-losses",data=auto,hue="drive-wheels")
